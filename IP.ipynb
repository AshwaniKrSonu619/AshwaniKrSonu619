# %% [markdown]
# <a href="https://colab.research.google.com/github/AshwaniKrSonu619/AshwaniKrSonu619/blob/master/IP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Rohan':'15000','Mohan':'20000','Neha':'25000'}
s = pd.Series(data)
print(s)
# Out:
# Rohan    15000
# Mohan    20000
# Neha     25000
# dtype: object

# %%
import pandas as pd
d1 = {'Employee Name': 'Rohan', 'Salary': 60000}
d2 = {'Employee Name': 'Mohan', 'Salary': 45000}
d3 = {'Employee Name': 'Ayush', 'Salary': 15000}
d4 = {'Employee Name': 'Ashwani', 'Salary': 30000}
data = [d1, d2, d3, d4]
df = pd.DataFrame(data)
print(df)
# Out:
#   Employee Name  Salary
# 0         Rohan   60000
# 1         Mohan   45000
# 2         Ayush   15000
# 3       Ashwani   30000

# %%
import matplotlib.pyplot as plt
import pandas as pd
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
df=pd.DataFrame({"height":height,"weight":weight})
#Set xlabel for the plot
plt.xlabel('Weight in kg')
#Set ylabel for the plot
plt.ylabel('Height in cm')
#Set chart title:
plt.title('Average weight with respect to average height')
#plot using marker'-*' and line colour as green
plt.plot(df.weight,df.height,marker='*',markersize=10,color='green',linewidth=2, linestyle='dashdot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
'radius': [2439.7, 6051.8, 6378.1]},
index=['Mercury', 'Venus', 'Earth'])
df.plot(kind='pie',y='mass')
plt.show()
